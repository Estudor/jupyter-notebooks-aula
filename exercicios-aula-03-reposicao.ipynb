# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
# Pratique usando o interpretador Python como uma calculadora:
#
# **Parte 1.** O volume de um cone de raio $r$ e altura $h$ é $\frac{1}{3} \pi r^2 h$.
# Qual é o volume de um cone de raio 3 e altura 7? Comece com uma variável chamada `radius` e outra chamada `height`, e depois atribua o resultado a uma variável chamada `volume`. Exiba o resultado. Adicione comentários para indicar que `radius` e `height` estão em centímetros e `volume` em centímetros cúbicos.

# %%
# Inclua aqui a resposta
radius = 0 #cm
height = 0 #cm
volume = 0 #cm3
radius = float(input("Radius: "))
height = float(input("Height: "))

volume = ((1/3*3.14) * (radius**2) * height)

print("volume: ", volume)
# Out:
# Radius: 15
# Height: 20
# volume:  4710.0

# %% [markdown]
# **Parte 2.** Uma regra da trigonometria diz que, para qualquer valor de $x$, $\sin(2x) = 2 \sin x \cos x$. Vamos ver se isso é verdade para um valor específico de $x$, como 2.5.
#
# Crie uma variável chamada `x` com esse valor.
# Depois use `math.sin` e `math.cos` para calcular os dois lados da igualdade e verifique se eles são iguais.
#
# Os dois resultados devem ficar bem próximos. Podem não ser exatamente iguais porque a aritmética de ponto flutuante não é exata (é apenas aproximadamente correta).

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 2
#
# Escreva uma função chamada `print_center` que recebe uma string chamada `valor` como parâmetro e exibe a string centralizada em uma tela de 40 colunas, ou seja, com espaços suficientes à esquerda para que a string fique no meio da tela.
#
# Exemplo:
#
# ```
# print_center("Univali")
# print_center("Universidade")
# print_center("Ciências da Computação")
# ```
#
# Saída
#
# ```
#                 Univali
#               Universidade
#          Ciências da Computação
# ```
#
# Dica: Use a função `len`, o operador de concatenação de strings (`+`), o operador de repetição de strings (`*`) e a divisão inteira (`//`) para descobrir quantos espaços ficam à esquerda.

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 3
#
# Agora que o Mário chegou ao topo, ele precisa descer do outro lado da fase.
#
# Crie uma função chamada `piramide_invertida` que recebe um inteiro chamado `altura` como parâmetro. A altura da pirâmide deve ser decidida pelo usuário.
#
# Exemplo: uma pirâmide invertida de altura 8 será:
#
# ```
# ########
#  #######
#   ######
#    #####
#     ####
#      ###
#       ##
#        #
# ```

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 4
#
# A música "5 Cafés na Cafeteira" começa com esta estrofe:
#
# > 5 cafés na cafeteira
# > 5 cafés para servir
# > Serve um, volta a programar
# > 4 cafés na cafeteira
#
# Então a segunda estrofe é igual, exceto que começa com 4 cafés e termina com 3. A música continua até que existam **0 cafés na cafeteira**.
#
# Escreva uma função chamada `cafe_verse` que recebe o número de cafés como parâmetro (`num_cafes`) e exibe a estrofe que começa com o número informado de cafés até não ter mais nenhum café.
#
# Saída esperada com 3 cafés:
#
# ```
# 3 cafés na cafeteira
# 3 cafés para servir
# Serve um, volta a programar
# 2 cafés na cafeteira
#
# 2 cafés na cafeteira
# 2 cafés para servir
# Serve um, volta a programar
# 1 cafés na cafeteira
#
# 1 cafés na cafeteira
# 1 cafés para servir
# Serve um, volta a programar
# 0 cafés na cafeteira
# ```

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 5
#
# Você está recebendo uma lista de preços representando os itens que um cliente colocou no carrinho da sua loja virtual e gostaria de calcular o total da compra.
#
# ```
# precos = [15.50, 8.00, 22.25, 30.00, 12.75]
# ```
#
# Crie um trecho de código que implemente essa solução.
#
# Saída esperada:
#
# ```
# O total da compra é de R$ 88.50.
# ```

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 6
#
# Uma colega de equipe está testando um cronômetro regressivo em uma aplicação. Durante os testes, ela percebeu que o sistema parou de responder, e suspeita que o problema está em um loop infinito.
#
# ```
# tempo_restante = 10
#
# while tempo_restante > 0:
#     print(f"Faltam {tempo_restante} segundos para o fim do teste...")
#     tempo_restante - 1
# ```
#
# Qual é o problema do código desenvolvido e como resolver?

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 7
#
# Você está desenvolvendo um sistema de reserva de assentos para um cinema. Um dos requisitos é verificar a quantidade de assentos livres em uma sessão e continuar aceitando reservas até que a sala fique lotada. Sempre que uma reserva é feita, o sistema deve informar o usuário e atualizar a quantidade disponível.
#
# Crie um trecho de código que simule as reservas de uma sessão com **6 assentos** livres. O programa deve exibir a mensagem "Reserva confirmada! Assentos restantes: `<QUANTIDADE>`" a cada reserva e, ao final, exibir a mensagem "Sessão lotada".
#
# Saída esperada:
#
# ```
# Reserva confirmada! Assentos restantes: 5
# Reserva confirmada! Assentos restantes: 4
# Reserva confirmada! Assentos restantes: 3
# Reserva confirmada! Assentos restantes: 2
# Reserva confirmada! Assentos restantes: 1
# Reserva confirmada! Assentos restantes: 0
# Sessão lotada
# ```

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 8
#
# Você está desenvolvendo uma nova funcionalidade para o sistema do cinema que interrompe a busca assim que um filme específico é encontrado. A lista de filmes já cadastrados no sistema é a seguinte:
#
# ```
# filmes = ["Matrix", "Cidade de Deus", "Interestelar", "O Poderoso Chefão", "Toy Story"]
# ```
#
# Crie um trecho de código que percorra a lista e exiba a mensagem "Filme encontrado: `<NOME_DO_FILME>`" assim que o filme **"Interestelar"** for encontrado. Após encontrar o filme, o programa deve parar imediatamente a busca, sem verificar os filmes restantes.
#
# Saída esperada:
#
# ```
# Filme encontrado: Interestelar
# ```

# %%
# Inclua aqui a resposta

# %% [markdown]
# ### Exercício 9
#
# Você está implementando um sistema de exibição da programação do cinema. A funcionalidade deve percorrer uma lista de sessões e exibir o nome de cada filme que ainda tem assentos disponíveis. No entanto, se a sessão estiver lotada, ela deve ser ignorada durante a iteração.
#
# ```
# sessoes = [
#     {"filme": "Matrix", "assentos": 12},
#     {"filme": "Cidade de Deus", "assentos": 0},
#     {"filme": "Interestelar", "assentos": 7},
#     {"filme": "O Poderoso Chefão", "assentos": 0},
#     {"filme": "Toy Story", "assentos": 4}
# ]
# ```
#
# Crie um trecho de código que exiba somente as sessões que possuem assentos disponíveis, no formato: "Sessão disponível: `<NOME_DO_FILME>`".
#
# Saída esperada:
#
# ```
# Sessão disponível: Matrix
# Sessão disponível: Interestelar
# Sessão disponível: Toy Story
# ```
#
# Dica: dentro do `for sessao in sessoes:`, cada `sessao` é um dicionário. Você pode acessar o número de assentos livres com `sessao["assentos"]`.

# %%
# Inclua aqui a resposta
