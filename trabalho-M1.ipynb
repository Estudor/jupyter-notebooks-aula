# %% [markdown]
# # Trabalho M1: Introdução à Programação com Python

# %% [markdown]
# ### Instruções de entrega
#
# 1. Escreva sua resposta **na célula de código logo abaixo de cada questão**. Não apague os enunciados.
# 2. Antes de entregar, execute **todas** as células na ordem (`Runtime -> Run all` / `Kernel -> Restart & Run All`) e **salve o notebook com as saídas visíveis**.
# 3. Não use recursos que ainda não foram estudados em aula.
# 4. Todas as funções pedidas devem ter **docstring** e nomes de variáveis significativos.
# 5. Trabalho **individual**.
#
# ### Critérios de avaliação
#
# | Critério | Peso |
# |---|---|
# | O programa funciona e produz a saída esperada | 50% |
# | Uso correto dos conceitos exigidos pela questão (funções, condicionais, laços, tipos) | 30% |
# | Legibilidade: nomes claros, comentários/docstrings, saída bem formatada | 20% |
#
#
# > **Atenção:** código que não executa (erro de sintaxe) não recebe a pontuação de funcionamento.
# > Se você não conseguir terminar uma questão, entregue a parte que funciona e explique em um comentário o que faltou.
#
# ### Uso de assistentes de IA
#
# O uso de assistentes é permitido para **tirar dúvidas**, mas você deve ser capaz de explicar cada linha do
# seu código. Na última célula do notebook há uma **declaração de uso de IA que deve ser preenchida**.

# %% [markdown]
# ---
#
# ## Parte 1: Variáveis, expressões, tipos e strings (3,0 pontos)

# %% [markdown]
# ### Questão 1: Orçamento de viagem (1,0 ponto)
#
# Escreva um programa que calcule o custo de uma viagem de carro.
#
# O programa deve ler do usuário, usando `input`:
#
# - a distância da viagem, em km (`float`);
# - o consumo médio do carro, em km/litro (`float`);
# - o preço do litro do combustível, em reais (`float`);
# - o valor total dos pedágios, em reais (`float`);
# - o número de pessoas que dividirão a despesa (`int`).
#
# Em seguida o programa deve calcular e exibir:
#
# 1. a quantidade de litros necessária (distância dividida pelo consumo);
# 2. o custo do combustível;
# 3. o custo total (combustível + pedágios);
# 4. o custo por pessoa;
# 5. o tipo (`type`) das variáveis da distância e do número de pessoas.
#
# Todos os valores em reais devem ser exibidos com **2 casas decimais** (use `round` ou formatação de string).
#
# Exemplo:
#
# ```
# Distância da viagem (km): 450
# Consumo médio (km/l): 12.5
# Preço do litro (R$): 5.89
# Total de pedágios (R$): 32.40
# Número de pessoas: 3
#
# Litros necessários: 36.0
# Custo do combustível: R$ 212.04
# Custo total da viagem: R$ 244.44
# Custo por pessoa: R$ 81.48
# Tipo da distância: <class 'float'> | Tipo do número de pessoas: <class 'int'>
# ```

# %%
# Inclua aqui a resposta
dist_V = float(input("Distância (km) da viagem? "))
cons_M = float(input("Consumo médio (km/l)? "))
preco_L = float(input("Preço (R$) do litro? "))
tot_P = float(input("Preço (R$) dos pedágios? "))
num_P = int(input("Número de pessoas: "))

lit_N = dist_V / cons_M
custo_C = cons_M * preco_L
custo_T = custo_C + tot_P
custo_TP = custo_T / num_P

print("\n Litros necessários: ",lit_N)
print("Custo do combustível: R$", custo_C)
print("Custo total da viagem: R$", custo_T)
print("Custo por pessoa: R$", custo_TP)
print("Tipo da distância: ", type(dist_V), "Tipo do número de pessoas:", type(num_P))
# Out:
# Distância (km) da viagem? 15
# Consumo médio (km/l)? 4
# Preço (R$) do litro? 20
# Preço (R$) dos pedágios? 13
# Número de pessoas: 2
#
#  Litros necessários:  3.75
# Custo do combustível: R$ 80.0
# Custo total da viagem: R$ 93.0
# Custo por pessoa: R$ 46.5
# Tipo da distância:  <class 'float'> Tipo do número de pessoas: <class 'int'>

# %% [markdown]
# ### Questão 2: Crachá do estudante (1,0 ponto)
#
# Escreva um programa que leia o **primeiro nome** e o **sobrenome** do usuário (em duas chamadas separadas de
# `input`) e monte um crachá com as informações abaixo:
#
# 1. o nome completo (primeiro nome + espaço + sobrenome);
# 2. o nome completo em MAIÚSCULAS e em minúsculas;
# 3. o total de letras do nome completo, **sem contar o espaço**;
# 4. as iniciais em maiúsculo, separadas por ponto (por exemplo, `A.S.`);
# 5. um e-mail sugerido no formato `primeironome.sobrenome@edu.br`, todo em minúsculas;
# 6. uma linha decorativa de `=` com o mesmo comprimento do nome completo (use o operador `*` de strings);
# 7. uma verificação booleana: a letra `"a"` aparece no nome completo em minúsculas? (use o operador `in` e exiba o valor `True`/`False`).
#
# Exemplo:
#
# ```
# Primeiro nome: Ana
# Sobrenome: Silva
#
# =========
# Ana Silva
# ANA SILVA
# ana silva
# Total de letras: 8
# Iniciais: A.S.
# E-mail: ana.silva@edu.br
# Contém a letra 'a': True
# =========
# ```

# %%
# Inclua aqui a resposta
primeiro_N = input("Primeiro nome: ")
segundo_N = input("Sobrenome: ")

nome_C = (primeiro_N + " " + segundo_N)

nome_Max = nome_C.upper()
nome_Min = nome_C.lower()

tot_L = len(nome_C.replace(" ", ""))

iniciais = (primeiro_N[0].upper() + "." + segundo_N[0].upper() + ".")

email = (primeiro_N.lower() + "." + segundo_N.lower() + "@edu.br")

linha = ("=" * len(nome_C))

cont_A = ("a" in nome_Min)

print("\n" + linha)
print(nome_C)
print(nome_Max)
print(nome_Min)
print("Total de letras:", tot_L)
print("Iniciais:", iniciais)
print("E-mail: ", email)
print("Contém a letra 'a':", cont_A)
print(linha)
# Out:
# Primeiro nome: Ronaldo
# Sobrenome: Silva
#
# =============
# Ronaldo Silva
# RONALDO SILVA
# ronaldo silva
# Total de letras: 12
# Iniciais: R.S.
# E-mail:  ronaldo.silva@edu.br
# Contém a letra 'a': True
# =============

# %% [markdown]
# ### Questão 3: Distância entre dois pontos (1,0 ponto)
#
# Usando a instrução `import` e o módulo `math`, escreva um programa que:
#
# 1. leia as coordenadas de dois pontos do plano: `x1`, `y1`, `x2` e `y2` (todos `float`);
# 2. calcule `dx` e `dy` como as diferenças **em valor absoluto** entre as coordenadas;
# 3. calcule a distância entre os pontos com a fórmula abaixo:
#
# $$distancia = \sqrt{dx^2 + dy^2}$$
#
# 4. calcule a área do círculo que tem essa distância como raio;
# 5. exiba `dx`, `dy`, a distância e a área, todos arredondados para 2 casas decimais com `round`.
#
# Exemplo:
#
# ```
# x1: 1
# y1: 2
# x2: 4
# y2: 6
#
# dx = 3.0
# dy = 4.0
# Distância entre os pontos: 5.0
# Área do círculo de raio 5.0: 78.54
# ```

# %%
# Inclua aqui a resposta
import math

x1 = float(input("x1: "))
y1 = float(input("y1: "))
x2 = float(input("x2: "))
y2 = float(input("y2: "))

dx = abs(x2 - x1)
dy = abs(y2 - y1)

distancia = math.sqrt((dx**2) + (dy**2))

area = (math.pi * distancia**2)

print("\n dx =", round(dx, 2))
print("dy =", round(dy, 2))
print("Distância entre os pontos: ", round(distancia, 2))
print("Área do círculo de raio ", round(distancia, 2),":", round(area, 2))
# Out:
# x1: 2
# y1: 5
# x2: 8
# y2: 2
#
#  dx = 6.0
# dy = 3.0
# Distância entre os pontos:  6.71
# Área do círculo de raio  6.71 : 141.37

# %% [markdown]
# ---
#
# ## Parte 2: Funções, encapsulamento e generalização (3,0 pontos)

# %% [markdown]
# ### Questão 4: Encapsulamento e refatoração (1,0 ponto)
#
# O código abaixo calcula e exibe a média de três alunos. Ele **funciona**, mas repete a mesma lógica três vezes:
#
# ```python
# nota1 = 7.0
# nota2 = 5.5
# nota3 = 9.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Ana:", round(media, 2))
#
# nota1 = 4.0
# nota2 = 6.5
# nota3 = 5.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Bruno:", round(media, 2))
#
# nota1 = 9.5
# nota2 = 8.0
# nota3 = 10.0
# media = (nota1 + nota2 + nota3) / 3
# print("Média de Carla:", round(media, 2))
# ```
#
# Sua tarefa:
#
# **(a)** **Encapsule** essa lógica em uma função chamada `exibir_media(nome, nota1, nota2, nota3)`, que calcula a
# média das três notas e exibe a mensagem no mesmo formato. A função deve ter uma **docstring** descrevendo o que
# ela faz e o que significa cada parâmetro.
#
# **(b)** Chame a função três vezes para reproduzir exatamente a mesma saída do código original.
#
# **(c)** Na célula de texto indicada, explique com suas palavras: o que é **encapsulamento**, o que é
# **refatoração**, e por que a versão com função é melhor que a original.
#
# Saída esperada:
#
# ```
# Média de Ana: 7.17
# Média de Bruno: 5.17
# Média de Carla: 9.17
# ```

# %%
# Inclua aqui a resposta

"""Essa função retorna a média de um aluno, recebendo o nome do aluno, e suas 3 notas como argumentos."""

def exibir_media(nome, nota1, nota2, nota3):
  media = ((nota1 + nota2 + nota3) / 3)
  print("Média de", nome,":", round(media, 2))
exibir_media("Ana", 7.0, 5.5, 9.0)
exibir_media("Bruno", 4.0, 6.5, 5.0)
exibir_media("Carla", 9.5, 8.0, 10.0)
# Out:
# Média de Ana : 7.17
# Média de Bruno : 5.17
# Média de Carla : 9.17

# %% [markdown]
# **(c) Sua explicação sobre encapsulamento e refatoração:**
#
# _(escreva aqui — pelo menos 3 linhas)_
#
# Encapsulamento é uma forma de controle de acesso de dados, como deixando variaveis privadas para que apenas podem ser acessadas por funções. Enquanto refatoração é um termo que se refere a quando se refaz um código/algoritmo (geralmente para melhorar otimização) sem mudar seu funcionamento externo. Um exemplo disso é o próprio exercicio 4.
#
# A versão com função é melhor pois não se repete o mesmo algoritmo de calculo de média e print 3 vezes, em vez disso apenas se usa uma função que faz isso 3 vezes.

# %% [markdown]
# ### Questão 5: Generalização, parâmetros e variáveis locais (1,0 ponto)
#
# **(a)** Escreva uma função chamada `moldura(texto, caractere, largura)` que exibe um texto dentro de uma moldura.
# A função deve:
#
# - imprimir uma linha formada pela repetição de `caractere`, com a `largura` especificada;
# - imprimir o `texto` entre dois `caractere` (um no início e outro no fim da linha);
# - imprimir novamente a linha de fechamento.
#
# A função deve ter uma **docstring**. Note que ela **não retorna valor**, apenas exibe (retorna `None`).
#
# Exemplo:
#
# ```
# moldura("Trabalho 1", "*", 20)
# ```
#
# Saída:
#
# ```
# ********************
# * Trabalho 1
# ********************
# ```
#
# **(b)** Chame `moldura` **três vezes**, com textos, caracteres e larguras diferentes, mostrando que a função foi
# **generalizada** pelos parâmetros.

# %%
# Inclua aqui a resposta

"""Essa função exibe um texto (texto), com um caractere (caractere) repetido pelo valor de largura (largura) em volta, como uma moldura."""

def moldura(texto, caractere, largura):
  print(caractere * largura)
  print(caractere, texto)
  print(caractere * largura)

moldura("Trabalho 1", '*', 20)
moldura("Trabalho doix", '-', 25)
moldura("Trabalho um mais um mais um", '¨', 35)
# Out:
# ********************
# * Trabalho 1
# ********************
# -------------------------
# - Trabalho doix
# -------------------------
# ¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨
# ¨ Trabalho um mais um mais um
# ¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨¨

# %% [markdown]
# ### Questão 6: Desenhando com `jupyturtle` (1,0 ponto)
#
# Não esqueça de baixar o módulo `jupyturtle` antes de resolver a questão.

# %% [markdown]
# **(a)** Escreva uma função chamada `poligono(lados, tamanho)` que desenhe um polígono regular com o número de lados e o comprimento de lado informados. A função deve ter docstring.
#
# **(b)** Escreva uma função chamada `flor(petalas, lados, tamanho)` que **reutilize** `poligono` para desenhar
# uma flor.
#
# **(c)** Faça três desenhos: um triângulo, um hexágono e uma flor.
#
# Exemplo:
#
# ```
# make_turtle()
# flor(8, 4, 30)
# ```

# %%
# (a) e (b) defina aqui as funções poligono e flor
from jupyturtle import *

"""Gera um poligono com (lados) lados, cada lado tendo (tamanho) de comprimento."""

def poligono(lados, tamanho):
  for i in range(lados):
    fd(tamanho)
    lt(360/lados)
    fd(tamanho)
"""Gera uma flor com (petalas) petalas, com (lados) lados, com cada lado tendo (tamanho) de comprimento."""
def flor(petalas, lados, tamanho):
  make_turtle()
  poligono(10, 3)
  for i in range(petalas):
    poligono(lados, tamanho)
    left(360/petalas)

# %%
# (c) triângulo
make_turtle()
poligono(3, 4)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="154.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.0" y1="75.0" x2="152.0" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="152.0" y1="71.5" x2="150.0" y2="68.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="68.1" x2="148.0" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="148.0" y1="71.5" x2="146.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="146.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# (c) hexágono
make_turtle()
poligono(6, 5)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="155.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="75.0" x2="157.5" y2="70.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.5" y1="70.7" x2="160.0" y2="66.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="160.0" y1="66.3" x2="157.5" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.5" y1="62.0" x2="155.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.0" y1="57.7" x2="150.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="57.7" x2="145.0" y2="57.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.0" y1="57.7" x2="142.5" y2="62.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.5" y1="62.0" x2="140.0" y2="66.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.0" y1="66.3" x2="142.5" y2="70.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.5" y1="70.7" x2="145.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
# (c) flor
flor(4, 8, 7)
# Out:
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="153.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.0" y1="75.0" x2="155.4" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.4" y1="73.2" x2="157.9" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.9" y1="71.5" x2="158.8" y2="68.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.8" y1="68.6" x2="159.7" y2="65.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.7" y1="65.8" x2="158.8" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="158.8" y1="62.9" x2="157.9" y2="60.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.9" y1="60.1" x2="155.4" y2="58.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="155.4" y1="58.3" x2="153.0" y2="56.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="153.0" y1="56.5" x2="150.0" y2="56.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="56.5" x2="147.0" y2="56.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.0" y1="56.5" x2="144.6" y2="58.3"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.6" y1="58.3" x2="142.1" y2="60.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.1" y1="60.1" x2="141.2" y2="62.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="62.9" x2="140.3" y2="65.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.3" y1="65.8" x2="141.2" y2="68.6"
#     stroke="#663399" stroke-width="2" />
# <line x1="141.2" y1="68.6" x2="142.1" y2="71.5"
#     stroke="#663399" stroke-width="2" />
# <line x1="142.1" y1="71.5" x2="144.6" y2="73.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="144.6" y1="73.2" x2="147.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="147.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="157.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="75.0" x2="161.9" y2="70.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.9" y1="70.1" x2="166.9" y2="65.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="65.1" x2="166.9" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="58.1" x2="166.9" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="51.1" x2="161.9" y2="46.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.9" y1="46.2" x2="157.0" y2="41.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="41.2" x2="150.0" y2="41.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="41.2" x2="143.0" y2="41.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.0" y1="41.2" x2="138.1" y2="46.2"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="46.2" x2="133.1" y2="51.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="51.1" x2="133.1" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="58.1" x2="133.1" y2="65.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="65.1" x2="138.1" y2="70.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="70.1" x2="143.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="150.0" y2="68.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="68.0" x2="145.1" y2="63.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.1" y1="63.1" x2="140.1" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.1" y1="58.1" x2="133.1" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="58.1" x2="126.1" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="58.1" x2="121.2" y2="63.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.2" y1="63.1" x2="116.2" y2="68.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.2" y1="68.0" x2="116.2" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.2" y1="75.0" x2="116.2" y2="82.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="116.2" y1="82.0" x2="121.2" y2="86.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="121.2" y1="86.9" x2="126.1" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="126.1" y1="91.9" x2="133.1" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="91.9" x2="140.1" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="140.1" y1="91.9" x2="145.1" y2="86.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="145.1" y1="86.9" x2="150.0" y2="82.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="82.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="143.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.0" y1="75.0" x2="138.1" y2="79.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="79.9" x2="133.1" y2="84.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="84.9" x2="133.1" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="91.9" x2="133.1" y2="98.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="133.1" y1="98.9" x2="138.1" y2="103.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="138.1" y1="103.8" x2="143.0" y2="108.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="143.0" y1="108.8" x2="150.0" y2="108.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="108.8" x2="157.0" y2="108.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="108.8" x2="161.9" y2="103.8"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.9" y1="103.8" x2="166.9" y2="98.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="98.9" x2="166.9" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="91.9" x2="166.9" y2="84.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="84.9" x2="161.9" y2="79.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="161.9" y1="79.9" x2="157.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="157.0" y1="75.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="75.0" x2="150.0" y2="82.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="82.0" x2="154.9" y2="86.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.9" y1="86.9" x2="159.9" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.9" y1="91.9" x2="166.9" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="91.9" x2="173.9" y2="91.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.9" y1="91.9" x2="178.8" y2="86.9"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="86.9" x2="183.8" y2="82.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.8" y1="82.0" x2="183.8" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.8" y1="75.0" x2="183.8" y2="68.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="183.8" y1="68.0" x2="178.8" y2="63.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="178.8" y1="63.1" x2="173.9" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="173.9" y1="58.1" x2="166.9" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="166.9" y1="58.1" x2="159.9" y2="58.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.9" y1="58.1" x2="154.9" y2="63.1"
#     stroke="#663399" stroke-width="2" />
# <line x1="154.9" y1="63.1" x2="150.0" y2="68.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="68.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ---
#
# ## Parte 3: Expressões booleanas e condicionais (2,0 pontos)

# %% [markdown]
# ### Questão 7: Funções booleanas e operadores lógicos (1,0 ponto)
#
# **(a)** Escreva uma função chamada `eh_bissexto(ano)` que **retorne** `True` se o ano for bissexto e `False` caso contrário. Use os operadores `%`, `and`, `or` e `not` em uma **única expressão booleana** no `return`
# (não use `if`).
#
# **(b)** Escreva uma função chamada `eh_triangulo(a, b, c)` que retorne `True` se três medidas podem formar um
# triângulo. A condição é que cada lado seja **positivo** e que cada lado seja **menor** que a soma dos outros dois.
#
# **(c)** Usando `for i in range(...)`, exiba para os anos de **1996 a 2005** se cada um é bissexto ou não.
#
# **(d)** Teste `eh_triangulo` com pelo menos três combinações diferentes, exibindo o resultado de cada teste.
#
# Exemplo:
#
# ```
# 1996 é bissexto? True
# 1997 é bissexto? False
# ...
# 2000 é bissexto? True
# ...
# eh_triangulo(3, 4, 5) -> True
# eh_triangulo(1, 2, 10) -> False
# eh_triangulo(-1, 4, 5) -> False
# ```

# %%
# Inclua aqui a resposta
def eh_bissexto(ano):
  resultado = (ano % 4 == 0)
  return print(ano, 'é bissexto?', resultado)

eh_bissexto(1996)
eh_bissexto(1997)

def eh_triangulo(a, b, c):
  resultado = ((a < a+b) and (b < a+c) and (c < a+b))
  print(resultado)

for i in range(1996, 2005):
  eh_bissexto(i)

eh_triangulo(3, 4, 5)
eh_triangulo(1, 2, 10)
eh_triangulo(1, 4, 5)
# Out:
# 1996 é bissexto? True
# 1997 é bissexto? False
# 1996 é bissexto? True
# 1997 é bissexto? False
# 1998 é bissexto? False
# 1999 é bissexto? False
# 2000 é bissexto? True
# 2001 é bissexto? False
# 2002 é bissexto? False
# 2003 é bissexto? False
# 2004 é bissexto? True
# True
# False
# False

# %% [markdown]
# ### Questão 8: Condicionais encadeadas e aninhadas (1,0 ponto)
#
# Escreva uma função chamada `classificar_imc(peso, altura)` que:
#
# 1. **valide os dados**: se `peso` **ou** `altura` for menor ou igual a zero, a função deve
#    retornar `None`, sem calcular nada;
# 2. caso os dados sejam válidos, calcule o IMC com a fórmula `imc = peso / altura ** 2`;
# 3. use uma **condicional encadeada** (`if`/`elif`/`else`) para **retornar** a classificação correspondente:
#
# | IMC | Classificação |
# |---|---|
# | menor que 18,5 | `"Abaixo do peso"` |
# | de 18,5 a 24,9 | `"Peso normal"` |
# | de 25,0 a 29,9 | `"Sobrepeso"` |
# | 30,0 ou mais | `"Obesidade"` |
#
# Depois, escreva um programa que leia o peso e a altura do usuário, chame a função e:
#
# - se o retorno for `None`, exiba a mensagem `"Dados inválidos: peso e altura devem ser positivos."`;
# - caso contrário, exiba o IMC arredondado com 2 casas decimais e a classificação.
#
# A função deve ter **docstring**.
#
# Exemplo:
#
# ```
# Peso (kg): 72.5
# Altura (m): 1.75
# IMC: 23.67 -> Peso normal
# ```
#
# ```
# Peso (kg): 70
# Altura (m): 0
# Dados inválidos: peso e altura devem ser positivos.
# ```

# %%
# Inclua aqui a resposta

""" Calcula o imc com (peso) sendo o peso, e (altura) sendo altura."""
def classificar_imc(peso, altura):
  if((peso or altura) <= 0):
    return None
  else:
    imc = (peso/altura ** 2)
    if(imc < 18.5):
      return "Abaixo do peso"
    elif(18.5 < imc):
      return "Peso normal"
    elif(25.0 < imc < 29.9):
      return "Sobrepeso"
    elif(imc > 30.0):
      return "Obesidade"

peso = float(input("Peso (kg): "))
altura = float(input("Altura (m): "))
teste = classificar_imc(peso, altura)
if teste is None:
  print("Dados inválidos: peso e altura devem ser positivos.")
else:
  imc = peso / altura ** 2
  print("IMC: ", imc, "->", teste)
# Out:
# Peso (kg): 70
# Altura (m): 1.20
# IMC:  48.611111111111114 -> Peso normal

# %% [markdown]
# ---
#
# ## Parte 4: Valores de retorno, `None` e docstrings (0,5 ponto)

# %% [markdown]
# ### Questão 9: `print` não é `return` (0,5 ponto)
#
# **(a)** Escreva duas funções, ambas com docstring:
#
# - `mostrar_dobro(numero)`: **exibe** o dobro do número com `print` e **não retorna nada**;
# - `calcular_dobro(numero)`: **retorna** o dobro do número, sem exibir nada.
#
# **(b)** Execute e observe os quatro comandos abaixo, mantendo as saídas visíveis:
#
# ```python
# mostrar_dobro(5)
# print(mostrar_dobro(5))
# calcular_dobro(5)
# print(calcular_dobro(5))
# ```
#
# **(c)** Mostre que o valor de retorno pode ser usado em uma expressão, por exemplo:
# `print(calcular_dobro(5) + calcular_dobro(10))`. Tente fazer o mesmo com `mostrar_dobro` e copie o erro em um
# comentário.
#
# **(d)** Na célula de texto indicada, responda:
#
# 1. Por que `print(mostrar_dobro(5))` exibe `None`?
# 2. Qual das duas funções é mais reaproveitável e por quê?
# 3. Para que serve uma **docstring** e em que ela se diferencia de um comentário comum? Cite um exemplo de ferramenta que **lê** a docstring das suas funções.

# %%
# (a) e (b) inclua aqui a resposta
def mostrar_dobro(numero):
  print(numero*2)
def calcular_dobro(numero):
  return numero*2

mostrar_dobro(5)
print(mostrar_dobro(5))
calcular_dobro(5)
print(calcular_dobro(5))

print(calcular_dobro(5) + calcular_dobro(10))
print(mostrar_dobro(5) + mostrar_dobro(10))
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'
# Out:
# 10
# 10
# None
# 10
# 30
# 10
# 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3069/4057693355.py in <cell line: 0>()
#      11
#      12 print(calcular_dobro(5) + calcular_dobro(10))
# ---> 13 print(mostrar_dobro(5) + mostrar_dobro(10))
#      14 # TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'
#      15
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
# (c) inclua aqui a resposta

# %% [markdown]
# **(d) Suas respostas:**
#
# 1. _(Porque quando uma função não tem return, Python automaticamente retorna "None")_
# 2. _(calcular_dobro, já que não printa o valor direto, pode ser utilizado em uma fórmula ou para outra coisa)_
# 3. _(Uma docstring é utilizada para guiar um usuário de uma biblioteca com o que cada função faz, em vez de ter que buscar em uma documentação separada. Um exemplo de ferramente é o pydoc)_

# %% [markdown]
# ---
#
# ## Parte 5: Plano de desenvolvimento e desenvolvimento incremental (1,5 ponto)

# %% [markdown]
# ### Questão 10: Boletim da turma (1,5 ponto)
#
# Escreva um programa que gere o boletim de uma turma.
#
# O programa deve:
#
# 1. ler a quantidade de alunos (`int`);
# 2. para cada aluno:
#    - ler o nome (`str`) e três notas (`float`);
#    - calcular a média com uma função `media_notas(nota1, nota2, nota3)` que **retorna** o valor;
#    - obter a situação com uma função `situacao(media)` que **retorna** `"Aprovado"` (média maior ou igual a 7),
#      `"Recuperação"` (média maior ou igual a 4 e menor que 7) ou `"Reprovado"` (média menor que 4);
#    - exibir uma linha do boletim com o nome, a média (1 casa decimal) e a situação;
# 3. ao final, exibir:
#    - a média geral da turma (2 casas decimais);
#    - a quantidade e o **percentual** de aprovados;
#    - o nome do aluno com a maior média.
#
# Todas as funções devem ter **docstring**.
#
# Exemplo:
#
# ```
# Quantos alunos? 3
#
# Aluno 1 - nome: Ana
# Nota 1: 7
# Nota 2: 5.5
# Nota 3: 9
# Aluno 2 - nome: Bruno
# Nota 1: 4
# Nota 2: 3
# Nota 3: 2
# Aluno 3 - nome: Carla
# Nota 1: 9.5
# Nota 2: 8
# Nota 3: 10
#
# ===== BOLETIM =====
# Ana: 7.2 - Aprovado
# Bruno: 3.0 - Reprovado
# Carla: 9.2 - Aprovado
# ===================
# Média geral da turma: 6.44
# Aprovados: 2 de 3 (66.67%)
# Melhor média: Carla (9.17)
# ```
#
# **(a) Plano de desenvolvimento:** *antes* de programar, descreva na célula de
# texto abaixo o seu plano: quais funções você vai criar, quais parâmetros cada uma recebe, o que cada uma retorna e em que ordem você vai construir o programa.
#
# **(b) Desenvolvimento incremental:** escreva o programa em etapas, testando cada uma. Nas células de código indicadas, mantenha as **três versões**:
#
# - **Versão 1:** apenas as funções `media_notas` e `situacao`, testadas com valores fixos (sem `input`).
# - **Versão 2:** o laço que lê os alunos e exibe as linhas do boletim.
# - **Versão 3:** a versão final, com as estatísticas do final do boletim.
#
# **(c)** Ao final, comente na célula de texto o que mudou de uma versão para a outra e qual erro você encontrou (e corrigiu) durante o processo.

# %% [markdown]
# **(a) Seu plano de desenvolvimento:**
#
# _(Por conta da parte de ler a quantidade de alunos, comparar valores, além de ter que repetir a mesma coisa para 3 alunos, vou usar um loop para pegar as informações, depois usar as 2 funções media_notas e situacao, e no fim printar tudo, seguindo o exemplo)_

# %%
# Versão 1 - somente as funções, testadas com valores fixos

def media_notas(nota1, nota2, nota3):
  media = (nota1+nota2+nota3)/3
  return media

def situacao(media):
  if(media > 7):
    return 'aprovado'
  elif(4 < media < 7):
    return 'recuperação'
  else: return 'reprovado'

print(media_notas(8,9,6))
print(situacao(media_notas(8,9,6)))
# Out:
# 7.666666666666667
# aprovado

# %%
# Versão 2 - laço de leitura e linhas do boletim

alunos = []
notas1 = []
notas2 = []
notas3 = []
medias = []

def media_notas(nota1, nota2, nota3):
  media = (nota1+nota2+nota3)/3
  return media

def situacao(media):
  if(media > 7):
    return 'aprovado'
  elif(4 <= media < 7):
    return 'recuperação'
  else: return 'reprovado'

quant_A = int(input("Escreva a quantidade de alunos: "))

for i in range(0, quant_A):
  aluno = str(input("Escreva o nome do aluno(a): "))
  alunos.append(aluno)
  nota1 = float(input("Escreva a nota 1 do aluno(a): "))
  notas1.append(nota1)
  nota2 = float(input("Escreva a nota 2 do aluno(a): "))
  notas2.append(nota2)
  nota3 = float(input("Escreva a nota 3 do aluno(a): "))
  notas3.append(nota3)

  medias.append(media_notas(nota1, nota2, nota3))

print("========== BOLETIM ==========")
for i in range(0, quant_A):
  print(alunos[i], ":", medias[i], "-", situacao(medias[i]))
print("=============================")
# Out:
# Escreva a quantidade de alunos: 3
# Escreva o nome do aluno(a): Ronaldo
# Escreva a nota 1 do aluno(a): 6.0
# Escreva a nota 2 do aluno(a): 9.0
# Escreva a nota 3 do aluno(a): 3.0
# Escreva o nome do aluno(a): Santos
# Escreva a nota 1 do aluno(a): 1.0
# Escreva a nota 2 do aluno(a): 3.0
# Escreva a nota 3 do aluno(a): 5.0
# Escreva o nome do aluno(a): João
# Escreva a nota 1 do aluno(a): 8.0
# Escreva a nota 2 do aluno(a): 4.0
# Escreva a nota 3 do aluno(a): 7.0
# ========== BOLETIM ==========
# Ronaldo : 6.0 - recuperação
# Santos : 3.0 - reprovado
# João : 6.333333333333333 - recuperação
# =============================

# %%
# Versão 3 - versão final, com as estatísticas da turma

alunos = []
notas1 = []
notas2 = []
notas3 = []
medias = []
aprovados = 0
mediaT = 0
melhorM = 0
melhorM_A = ""

def media_notas(nota1, nota2, nota3):
  media = (nota1+nota2+nota3)/3
  return media

def situacao(media):
  if(media > 7):
    return 'aprovado'
  elif(4 <= media < 7):
    return 'recuperação'
  else: return 'reprovado'

quant_A = int(input("Escreva a quantidade de alunos: "))

for i in range(0, quant_A):
  aluno = str(input("Escreva o nome do aluno(a): "))
  alunos.append(aluno)
  nota1 = float(input("Escreva a nota 1 do aluno(a): "))
  notas1.append(nota1)
  nota2 = float(input("Escreva a nota 2 do aluno(a): "))
  notas2.append(nota2)
  nota3 = float(input("Escreva a nota 3 do aluno(a): "))
  notas3.append(nota3)

  medias.append(media_notas(nota1, nota2, nota3))

print("========== BOLETIM ==========")
for i in range(0, quant_A):
  print(alunos[i], ":", medias[i], "-", situacao(medias[i]))

  if(medias[i] > melhorM):
    melhorM = medias[i]
    maiorM_A = alunos[i]

  if(situacao(medias[i]) == 'aprovado'):
    aprovados +=1

  mediaT += medias[i]
mediaT = (mediaT/quant_A)
print("=============================")
print("Média geral da turma:", mediaT)
print("Aprovados:", aprovados, " de ", quant_A, f"({100/quant_A * aprovados}%)")
print("Melhor média: ", melhorM_A, ":", melhorM)
# Out:
# Escreva a quantidade de alunos: 3
# Escreva o nome do aluno(a): Bacalhau
# Escreva a nota 1 do aluno(a): 1.0
# Escreva a nota 2 do aluno(a): 5.0
# Escreva a nota 3 do aluno(a): 3.0
# Escreva o nome do aluno(a): Ronaldo
# Escreva a nota 1 do aluno(a): 9.0
# Escreva a nota 2 do aluno(a): 8.0
# Escreva a nota 3 do aluno(a): 6.0
# Escreva o nome do aluno(a): José
# Escreva a nota 1 do aluno(a): 5.0
# Escreva a nota 2 do aluno(a): 7.0
# Escreva a nota 3 do aluno(a): 4.0
# ========== BOLETIM ==========
# Bacalhau : 3.0 - reprovado
# Ronaldo : 7.666666666666667 - aprovado
# José : 5.333333333333333 - recuperação
# =============================
# Média geral da turma: 5.333333333333333
# Aprovados: 1  de  3 (33.333333333333336%)
# Melhor média:   : 7.666666666666667

# %% [markdown]
# **(c) O que mudou entre as versões e quais erros você corrigiu:**
#
# _(Versão 1 -> 2: laços for para entrada de dados (alunos, notas) e print do boletim
#   Versão 2 -> 3: laços para algoritmo de melhor notas, quantidade de aprovados, variaveis para os algoritmos adicionadas.
#   Nenhum erro foi encontrado trabalhando entre versões.)_

# %% [markdown]
# ---
#
# ## Declaração de uso de assistentes de IA
#
# Preencha honestamente:
#
# - **Usei assistente de IA neste trabalho?** ( ) Não  (X) Sim
# - **Em quais questões e para quê?** _(Na questão 6 para pesquisar como fazer a flor, na  questão 8 para entender o que estava errado no algoritmo, na questão 9 para tirar duvidas em algumas perguntas, na questão 10 para pesquisar sobre manipulação de arrays)_
# - **Declaro que sou capaz de explicar cada linha do código entregue:** (X) Sim
#
# ---
#
# **Happy Coding! 🐍**
